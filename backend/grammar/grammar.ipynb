# %%
"""
Module handles the parallel grammar based information extraction

"""
import sys
sys.path.append("..")

import requests
import concurrent
from searchBackend.parallelSearch import DistributedSearch
import json
# Out:
# c:\Users\saurav\anaconda3\envs\context\lib\site-packages\requests\__init__.py:109: RequestsDependencyWarning: urllib3 (1.26.13) or chardet (None)/charset_normalizer (3.1.0) doesn't match a supported version!
#   warnings.warn(

# %%
        
class DistributedGrammar(DistributedSearch):
    """
        Send request to multiple index server parallely

    """
    def __init__(self,config) -> None:
        self.grammar_endpoint = "api/execute/grammar"
        
        if not config:
            raise ValueError("Config not provided")
        self.config = config

        ## Loading array of IP and ports of index server
        if self.config.get("serverAddressList"):
            self.urlList = [
                f"http://{url}/" for url in self.config.get("serverAddressList")
            ]
        else:
            raise ValueError("serverAddressList not provided")
        
        self.headers = {
                        "Accept": "application/json",
                        "Content-Type": "application/json"
                        }

    def response_processor(self, response):
        """
            Transforming the response in the format of search api endpoint

        """

        duration = response.get("total_hits_duration")
        query = response.get("query")
        count = response.get("total_hits_count")
        complete = True
        total_hits = [item for key,value in response.get("total_hits").items() for item in value] ## Here they have match not matches
     

        ##TODO: Fix match/matches in frontend

        return {"complete":complete,
                "query":query,
                "count":count,
                "duration":duration,
                "scores":None,
                "total_hits":total_hits,
                "is_error":response.get("is_error"),
                "error_message":response.get("error_messages")
                }

    


        pass
        
    def query(self, url, search_query,maxDocs,triggerOverlap):
        """
            Pass Grammar query to this single endpoint

        """

        try:
            encoded_search_query = {
                        "grammar": search_query,
                        "maxDocs": maxDocs,
                        "allowTriggerOverlaps":triggerOverlap}
            
            search_url = f"{url}{self.grammar_endpoint}"  ## Final encoded query for search

            ## no encoding of response required
            response = requests.post(search_url,
                                     json=encoded_search_query,
                                     headers=self.headers)

            ## error in response.json will be catched by exception
            return {"status":"success","response":response.json()}

        except Exception as e:
            return {"status":"fail","response":{},"error_message": str(e)}
        
    def parallel_search(self, query_string,maxDocs,triggerOverlap):
        """
        Send reqest to multiple endpoints parallely and reterive the result from there.
        """

        total_hits = {}  ## key will be port and value as list of hit document
        total_duration = 0
        total_hits_count = 0
        error_messages = None
        is_error = False

        with concurrent.futures.ThreadPoolExecutor() as executor:

            ### TODO: Provide flexible option for Variable URL as well
            futures = {
                    executor.submit(self.query,
                                    url,
                                    query_string,
                                    maxDocs,
                                    triggerOverlap): url for url in self.urlList
                }

            for future in concurrent.futures.as_completed(futures):
                port = futures[future]

                try:
                    response = future.result()

                    if response.get("status") == "success":

                        response = response.get("response",{})
                        ## Total time taken
                        duration = response.get("duration") ## Time taken for the search
                        total_duration += duration

                        ## Total hits count
                        mentions = response.get("mentions")

                        ## Total number of hits
                        hits = len(mentions)
                        total_hits_count += hits
                        
                        total_hits[port] = mentions
                        
                        print(
                            f"Search on endpoint {port} completed. Hits: {hits}, Duration: {duration}"
                        )
                    
                    else:
                        error_messages = response.get("error_message")
                        is_error = True

                except Exception as e:
                    print(f"Error processing results from endpoint {port}: {e}")

        return {"total_hits": total_hits,
                "query": query_string,
                "total_hits_count": total_hits_count,
                "total_hits_duration":total_duration,
                "error_messages":error_messages,
                "is_error":is_error}
    
    def search(self, query_string,maxDocs,triggerOverlap):
        """
        public facing interface

        """
        return self.response_processor(self.parallel_search(query_string,maxDocs,triggerOverlap))

# %%
with open("../config.json", "r") as f:
    config = json.load(f)

# %%
config.get("distributed_custom_search")
# Out:
# {'port_range': [8585, 8594],
#  'serverAddressList': ['217.76.56.90:9000',
#   '217.76.56.90:8000',
#   '217.76.62.78:9000',
#   '217.76.62.78:8000',
#   '184.174.36.238:9000',
#   '184.174.36.238:8000',
#   '217.76.62.73:9000',
#   '217.76.55.207:9000',
#   '217.76.55.207:8000']}

# %%
grammar = DistributedGrammar(config=config.get("distributed_custom_search"))

# %%
QUERY= """
rules:
  - name: "rule2"
    label: Phosphorylation
    type:  event
    priority: 1
    pattern: |
      trigger = [lemma=/phosph.*/ & tag=/N.*/]
      subject = >nsubj []
"""

# %%
QUERY
# Out:
# '\nrules:\n  - name: "rule2"\n    label: Phosphorylation\n    type:  event\n    priority: 1\n    pattern: |\n      trigger = [lemma=/phosph.*/ & tag=/N.*/]\n      subject = >nsubj []\n'

# %%
res = grammar.search(QUERY,maxDocs=10,triggerOverlap=False)
# Out:
# Search on endpoint http://217.76.56.90:9000/ completed. Hits: 20, Duration: 0.19499999284744263
# Search on endpoint http://184.174.36.238:9000/ completed. Hits: 20, Duration: 0.1599999964237213
# Search on endpoint http://217.76.55.207:8000/ completed. Hits: 20, Duration: 0.10300000011920929
# Search on endpoint http://217.76.56.90:8000/ completed. Hits: 20, Duration: 0.2160000056028366
# Search on endpoint http://217.76.55.207:9000/ completed. Hits: 20, Duration: 0.13600000739097595
# Search on endpoint http://217.76.62.73:9000/ completed. Hits: 20, Duration: 0.21400000154972076
# Search on endpoint http://184.174.36.238:8000/ completed. Hits: 20, Duration: 0.2029999941587448
# Search on endpoint http://217.76.62.78:8000/ completed. Hits: 20, Duration: 0.3310000002384186
# Search on endpoint http://217.76.62.78:9000/ completed. Hits: 20, Duration: 0.4090000092983246

# %%
res.keys()
# Out:
# dict_keys(['complete', 'query', 'count', 'duration', 'scores', 'total_hits', 'is_error', 'error_message'])

# %%
res["is_error"]
# Out:
# True

# %%
res["error_message"]
# Out:
# 'Expecting value: line 1 column 1 (char 0)'

# %%
[item for key,value in res.get("total_hits").items() for item in value]
# Out:
# [{'sentenceId': 509617,
#   'label': None,
#   'documentId': '12525665',
#   'sentenceIndex': 3,
#   'words': ['Protein',
#    'phosphatase',
#    '2A',
#    '(',
#    'PP2A',
#    ')',
#    'is',
#    'a',
#    'phosphoprotein',
#    'that',
#    'plays',
#    'important',
#    'roles',
#    'in',
#    'the',
#    'regulation',
#    'of',
#    'signal',
#    'transduction',
#    'and',
#    'cell',
#    'growth',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 2, 'end': 3, 'namedCaptures': []}]},
#  {'sentenceId': 584575,
#   'label': None,
#   'documentId': '12196103',
#   'sentenceIndex': 2,
#   'words': ['14',
#    '-',
#    '3',
#    '-',
#    '3',
#    'proteins',
#    'bind',
#    'phosphoserine-phosphorylated',
#    'ligands',
#    ',',
#    'such',
#    'as',
#    'the',
#    'Raf-1',
#    'kinase',
#    'and',
#    'Bad',
#    ',',
#    'through',
#    'recognition',
#    'of',
#    'the',
#    'phosphorylated',
#    'consensus',
#    'motif',
#    ',',
#    'RSXpSXP',
#    '(',
#    'where',
#    'pS',
#    'is',
#    'phosphoserine',
#    ')',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 29, 'end': 30, 'namedCaptures': []}]},
#  {'sentenceId': 509617,
#   'label': 'Phosphorylation',
#   'documentId': '12525665',
#   'sentenceIndex': 3,
#   'words': ['Protein',
#    'phosphatase',
#    '2A',
#    '(',
#    'PP2A',
#    ')',
#    'is',
#    'a',
#    'phosphoprotein',
#    'that',
#    'plays',
#    'important',
#    'roles',
#    'in',
#    'the',
#    'regulation',
#    'of',
#    'signal',
#    'transduction',
#    'and',
#    'cell',
#    'growth',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 8,
#     'end': 9,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 2, 'end': 3, 'namedCaptures': []}}]}]},
#  {'sentenceId': 335388,
#   'label': None,
#   'documentId': '14611633',
#   'sentenceIndex': 1,
#   'words': ['Phospholipids',
#    'are',
#    'an',
#    'essential',
#    'component',
#    'of',
#    'all',
#    'mammalian',
#    'cells',
#    ';',
#    'platelet',
#    'activating',
#    'factor',
#    '(',
#    'PAF=1-O-alkyl-acetyl-sn-glycero-3-phosphocholine',
#    ')',
#    'is',
#    'a',
#    'signalling',
#    'phospholipid',
#    'that',
#    'has',
#    'many',
#    'biological',
#    'properties',
#    'in',
#    'addition',
#    'to',
#    'platelet',
#    'activation',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 12, 'end': 13, 'namedCaptures': []}]},
#  {'sentenceId': 584575,
#   'label': 'Phosphorylation',
#   'documentId': '12196103',
#   'sentenceIndex': 2,
#   'words': ['14',
#    '-',
#    '3',
#    '-',
#    '3',
#    'proteins',
#    'bind',
#    'phosphoserine-phosphorylated',
#    'ligands',
#    ',',
#    'such',
#    'as',
#    'the',
#    'Raf-1',
#    'kinase',
#    'and',
#    'Bad',
#    ',',
#    'through',
#    'recognition',
#    'of',
#    'the',
#    'phosphorylated',
#    'consensus',
#    'motif',
#    ',',
#    'RSXpSXP',
#    '(',
#    'where',
#    'pS',
#    'is',
#    'phosphoserine',
#    ')',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 31,
#     'end': 32,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 29, 'end': 30, 'namedCaptures': []}}]}]},
#  {'sentenceId': 335388,
#   'label': 'Phosphorylation',
#   'documentId': '14611633',
#   'sentenceIndex': 1,
#   'words': ['Phospholipids',
#    'are',
#    'an',
#    'essential',
#    'component',
#    'of',
#    'all',
#    'mammalian',
#    'cells',
#    ';',
#    'platelet',
#    'activating',
#    'factor',
#    '(',
#    'PAF=1-O-alkyl-acetyl-sn-glycero-3-phosphocholine',
#    ')',
#    'is',
#    'a',
#    'signalling',
#    'phospholipid',
#    'that',
#    'has',
#    'many',
#    'biological',
#    'properties',
#    'in',
#    'addition',
#    'to',
#    'platelet',
#    'activation',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 19,
#     'end': 20,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 12, 'end': 13, 'namedCaptures': []}}]}]},
#  {'sentenceId': 589599,
#   'label': None,
#   'documentId': '12358754',
#   'sentenceIndex': 2,
#   'words': ['A',
#    'major',
#    'post-translational',
#    'mechanism',
#    'that',
#    'can',
#    'rapidly',
#    'regulate',
#    'GABAAR',
#    'function',
#    'is',
#    'receptor',
#    'phosphorylation',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 3, 'end': 4, 'namedCaptures': []}]},
#  {'sentenceId': 589599,
#   'label': 'Phosphorylation',
#   'documentId': '12358754',
#   'sentenceIndex': 2,
#   'words': ['A',
#    'major',
#    'post-translational',
#    'mechanism',
#    'that',
#    'can',
#    'rapidly',
#    'regulate',
#    'GABAAR',
#    'function',
#    'is',
#    'receptor',
#    'phosphorylation',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 12,
#     'end': 13,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 3, 'end': 4, 'namedCaptures': []}}]}]},
#  {'sentenceId': 437819,
#   'label': 'Phosphorylation',
#   'documentId': '14966281',
#   'sentenceIndex': 8,
#   'words': ['Wg',
#    'suppresses',
#    'Zw3-',
#    'but',
#    'not',
#    'CKIalpha-mediated',
#    'Arm',
#    'phosphorylation',
#    ',',
#    'indicating',
#    'that',
#    'a',
#    'vital',
#    'regulatory',
#    'step',
#    'in',
#    'Wg',
#    'signaling',
#    'is',
#    'Zw3-mediated',
#    'Arm',
#    'phosphorylation',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 21,
#     'end': 22,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 14, 'end': 15, 'namedCaptures': []}}]}]},
#  {'sentenceId': 213241,
#   'label': 'Phosphorylation',
#   'documentId': '12932442',
#   'sentenceIndex': 1,
#   'words': ['MAP1B',
#    'is',
#    'a',
#    'major',
#    'microtubule-associated',
#    'phospho-protein',
#    'in',
#    'growing',
#    'axons',
#    'and',
#    'growth',
#    'cones',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 5,
#     'end': 6,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 0, 'end': 1, 'namedCaptures': []}}]}]},
#  {'sentenceId': 190734,
#   'label': None,
#   'documentId': '14663079',
#   'sentenceIndex': 1,
#   'words': ['Phosphatidylcholine',
#    '(',
#    'PC',
#    ')',
#    'is',
#    'the',
#    'major',
#    'membrane-forming',
#    'phospholipid',
#    'in',
#    'eukaryotes',
#    'with',
#    'important',
#    'structural',
#    'and',
#    'signalling',
#    'functions',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 0, 'end': 1, 'namedCaptures': []}]},
#  {'sentenceId': 213241,
#   'label': None,
#   'documentId': '12932442',
#   'sentenceIndex': 1,
#   'words': ['MAP1B',
#    'is',
#    'a',
#    'major',
#    'microtubule-associated',
#    'phospho-protein',
#    'in',
#    'growing',
#    'axons',
#    'and',
#    'growth',
#    'cones',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 0, 'end': 1, 'namedCaptures': []}]},
#  {'sentenceId': 437819,
#   'label': None,
#   'documentId': '14966281',
#   'sentenceIndex': 8,
#   'words': ['Wg',
#    'suppresses',
#    'Zw3-',
#    'but',
#    'not',
#    'CKIalpha-mediated',
#    'Arm',
#    'phosphorylation',
#    ',',
#    'indicating',
#    'that',
#    'a',
#    'vital',
#    'regulatory',
#    'step',
#    'in',
#    'Wg',
#    'signaling',
#    'is',
#    'Zw3-mediated',
#    'Arm',
#    'phosphorylation',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 14, 'end': 15, 'namedCaptures': []}]},
#  {'sentenceId': 170918,
#   'label': 'Phosphorylation',
#   'documentId': '14662652',
#   'sentenceIndex': 1,
#   'words': ['Lysophosphatidylcholine',
#    '(',
#    'LPC',
#    ')',
#    'is',
#    'an',
#    'endogenous',
#    'phospholipid',
#    'released',
#    'from',
#    'the',
#    'cell',
#    'membrane',
#    'during',
#    'ischemia',
#    ',',
#    'and',
#    'it',
#    'has',
#    'potent',
#    'cardiac',
#    'effects',
#    ',',
#    'including',
#    'inhibition',
#    'of',
#    'atrial',
#    'natriuretic',
#    'peptide',
#    '(',
#    'ANP',
#    ')',
#    'release',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 7,
#     'end': 8,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 0, 'end': 1, 'namedCaptures': []}}]}]},
#  {'sentenceId': 40874,
#   'label': None,
#   'documentId': '14561731',
#   'sentenceIndex': 5,
#   'words': ['XDbf4',
#    'was',
#    'a',
#    'phosphoprotein',
#    'in',
#    'interphase',
#    'extracts',
#    ',',
#    'and',
#    'was',
#    'apparently',
#    'hyperphosphorylated',
#    'in',
#    'cytostatic',
#    'factor',
#    '(CSF)-mediated',
#    ',',
#    'metaphase-arrested',
#    'extracts',
#    'and',
#    'in',
#    'mitotic',
#    'extracts',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 0, 'end': 1, 'namedCaptures': []}]},
#  {'sentenceId': 190734,
#   'label': 'Phosphorylation',
#   'documentId': '14663079',
#   'sentenceIndex': 1,
#   'words': ['Phosphatidylcholine',
#    '(',
#    'PC',
#    ')',
#    'is',
#    'the',
#    'major',
#    'membrane-forming',
#    'phospholipid',
#    'in',
#    'eukaryotes',
#    'with',
#    'important',
#    'structural',
#    'and',
#    'signalling',
#    'functions',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 8,
#     'end': 9,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 0, 'end': 1, 'namedCaptures': []}}]}]},
#  {'sentenceId': 109373,
#   'label': None,
#   'documentId': '12493752',
#   'sentenceIndex': 1,
#   'words': ['Bone',
#    'sialoprotein',
#    '(',
#    'BSP',
#    ')',
#    'is',
#    'a',
#    'highly',
#    'modified',
#    ',',
#    'anionic',
#    'phosphoprotein',
#    'that',
#    'is',
#    'expressed',
#    'almost',
#    'exclusively',
#    'in',
#    'mineralizing',
#    'connective',
#    'tissues',
#    'and',
#    'has',
#    'been',
#    'shown',
#    'to',
#    'be',
#    'a',
#    'potent',
#    'nucleator',
#    'of',
#    'hydroxyapatite',
#    '(',
#    'HA',
#    ')',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 1, 'end': 2, 'namedCaptures': []}]},
#  {'sentenceId': 109373,
#   'label': 'Phosphorylation',
#   'documentId': '12493752',
#   'sentenceIndex': 1,
#   'words': ['Bone',
#    'sialoprotein',
#    '(',
#    'BSP',
#    ')',
#    'is',
#    'a',
#    'highly',
#    'modified',
#    ',',
#    'anionic',
#    'phosphoprotein',
#    'that',
#    'is',
#    'expressed',
#    'almost',
#    'exclusively',
#    'in',
#    'mineralizing',
#    'connective',
#    'tissues',
#    'and',
#    'has',
#    'been',
#    'shown',
#    'to',
#    'be',
#    'a',
#    'potent',
#    'nucleator',
#    'of',
#    'hydroxyapatite',
#    '(',
#    'HA',
#    ')',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 11,
#     'end': 12,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 1, 'end': 2, 'namedCaptures': []}}]}]},
#  {'sentenceId': 40874,
#   'label': 'Phosphorylation',
#   'documentId': '14561731',
#   'sentenceIndex': 5,
#   'words': ['XDbf4',
#    'was',
#    'a',
#    'phosphoprotein',
#    'in',
#    'interphase',
#    'extracts',
#    ',',
#    'and',
#    'was',
#    'apparently',
#    'hyperphosphorylated',
#    'in',
#    'cytostatic',
#    'factor',
#    '(CSF)-mediated',
#    ',',
#    'metaphase-arrested',
#    'extracts',
#    'and',
#    'in',
#    'mitotic',
#    'extracts',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 3,
#     'end': 4,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 0, 'end': 1, 'namedCaptures': []}}]}]},
#  {'sentenceId': 170918,
#   'label': None,
#   'documentId': '14662652',
#   'sentenceIndex': 1,
#   'words': ['Lysophosphatidylcholine',
#    '(',
#    'LPC',
#    ')',
#    'is',
#    'an',
#    'endogenous',
#    'phospholipid',
#    'released',
#    'from',
#    'the',
#    'cell',
#    'membrane',
#    'during',
#    'ischemia',
#    ',',
#    'and',
#    'it',
#    'has',
#    'potent',
#    'cardiac',
#    'effects',
#    ',',
#    'including',
#    'inhibition',
#    'of',
#    'atrial',
#    'natriuretic',
#    'peptide',
#    '(',
#    'ANP',
#    ')',
#    'release',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 0, 'end': 1, 'namedCaptures': []}]},
#  {'sentenceId': 33320,
#   'label': 'Phosphorylation',
#   'documentId': '10858449',
#   'sentenceIndex': 1,
#   'words': ['Phosphatidylcholine',
#    '(',
#    'PC',
#    ')',
#    'is',
#    'the',
#    'major',
#    'membrane-forming',
#    'phospholipid',
#    'in',
#    'eukaryotes',
#    'and',
#    'can',
#    'be',
#    'synthesized',
#    'by',
#    'either',
#    'of',
#    'two',
#    'pathways',
#    ',',
#    'the',
#    'CDP-choline',
#    'pathway',
#    'or',
#    'the',
#    'methylation',
#    'pathway',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 8,
#     'end': 9,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 0, 'end': 1, 'namedCaptures': []}}]}]},
#  {'sentenceId': 67008,
#   'label': None,
#   'documentId': '11815618',
#   'sentenceIndex': 4,
#   'words': ['TBK-1',
#    'and',
#    'IKK-i',
#    'phosphorylate',
#    'Ser(36',
#    ')',
#    'of',
#    'IkappaBalpha',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 0, 'end': 1, 'namedCaptures': []}]},
#  {'sentenceId': 181131,
#   'label': 'Phosphorylation',
#   'documentId': '11083482',
#   'sentenceIndex': 6,
#   'words': ['After',
#    'further',
#    'adjustment',
#    'for',
#    'other',
#    'significant',
#    'dietary',
#    'factors',
#    ',',
#    'the',
#    'only',
#    'significant',
#    'remaining',
#    'associations',
#    'observed',
#    'were',
#    'for',
#    'phosphorus',
#    'and',
#    'fat',
#    'at',
#    'the',
#    'lumbar',
#    'spine',
#    ',',
#    'although',
#    'the',
#    'adjusted',
#    'goodness',
#    'of',
#    'fit',
#    'of',
#    'the',
#    'models',
#    'improved',
#    'compared',
#    'to',
#    'those',
#    'including',
#    'one',
#    'dietary',
#    'variable',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 17,
#     'end': 18,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 13, 'end': 14, 'namedCaptures': []}}]}]},
#  {'sentenceId': 100651,
#   'label': None,
#   'documentId': '9461591',
#   'sentenceIndex': 1,
#   'words': ['Platelet-activating',
#    'factor',
#    '(',
#    'PAF',
#    ')',
#    'is',
#    'a',
#    'potent',
#    'phospholipid',
#    'with',
#    'diverse',
#    'physiological',
#    'and',
#    'pathological',
#    'actions',
#    ',',
#    'and',
#    'it',
#    'is',
#    'inactivated',
#    'by',
#    'PAF',
#    'acetylhydrolase',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 1, 'end': 2, 'namedCaptures': []}]},
#  {'sentenceId': 53244,
#   'label': 'Phosphorylation',
#   'documentId': '9461674',
#   'sentenceIndex': 4,
#   'words': ['The',
#    'major',
#    '31P',
#    'NMR',
#    'signal',
#    'was',
#    'phosphocholine',
#    'phosphodiester',
#    'at',
#    'delta',
#    '0.22',
#    'ppm',
#    ':',
#    'significant',
#    'phosphodiester',
#    'signals',
#    'occurred',
#    'at',
#    'delta',
#    '1.15',
#    ',',
#    '1.33',
#    'and',
#    '1.47',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 7,
#     'end': 8,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 4, 'end': 5, 'namedCaptures': []}}]}]},
#  {'sentenceId': 211634,
#   'label': 'Phosphorylation',
#   'documentId': '10854908',
#   'sentenceIndex': 1,
#   'words': ['ARPP-21',
#    'is',
#    'a',
#    'cyclic',
#    'AMP-regulated',
#    'phosphoprotein',
#    'of',
#    'M(r',
#    ')',
#    '21',
#    'kDa',
#    'that',
#    'is',
#    'enriched',
#    'in',
#    'the',
#    'cell',
#    'bodies',
#    'and',
#    'terminals',
#    'of',
#    'medium-sized',
#    'spiny',
#    'neurons',
#    'in',
#    'the',
#    'basal',
#    'ganglia',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 5,
#     'end': 6,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 0, 'end': 1, 'namedCaptures': []}}]}]},
#  {'sentenceId': 53244,
#   'label': None,
#   'documentId': '9461674',
#   'sentenceIndex': 4,
#   'words': ['The',
#    'major',
#    '31P',
#    'NMR',
#    'signal',
#    'was',
#    'phosphocholine',
#    'phosphodiester',
#    'at',
#    'delta',
#    '0.22',
#    'ppm',
#    ':',
#    'significant',
#    'phosphodiester',
#    'signals',
#    'occurred',
#    'at',
#    'delta',
#    '1.15',
#    ',',
#    '1.33',
#    'and',
#    '1.47',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 4, 'end': 5, 'namedCaptures': []}]},
#  {'sentenceId': 33320,
#   'label': None,
#   'documentId': '10858449',
#   'sentenceIndex': 1,
#   'words': ['Phosphatidylcholine',
#    '(',
#    'PC',
#    ')',
#    'is',
#    'the',
#    'major',
#    'membrane-forming',
#    'phospholipid',
#    'in',
#    'eukaryotes',
#    'and',
#    'can',
#    'be',
#    'synthesized',
#    'by',
#    'either',
#    'of',
#    'two',
#    'pathways',
#    ',',
#    'the',
#    'CDP-choline',
#    'pathway',
#    'or',
#    'the',
#    'methylation',
#    'pathway',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 0, 'end': 1, 'namedCaptures': []}]},
#  {'sentenceId': 211634,
#   'label': None,
#   'documentId': '10854908',
#   'sentenceIndex': 1,
#   'words': ['ARPP-21',
#    'is',
#    'a',
#    'cyclic',
#    'AMP-regulated',
#    'phosphoprotein',
#    'of',
#    'M(r',
#    ')',
#    '21',
#    'kDa',
#    'that',
#    'is',
#    'enriched',
#    'in',
#    'the',
#    'cell',
#    'bodies',
#    'and',
#    'terminals',
#    'of',
#    'medium-sized',
#    'spiny',
#    'neurons',
#    'in',
#    'the',
#    'basal',
#    'ganglia',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 0, 'end': 1, 'namedCaptures': []}]},
#  {'sentenceId': 67008,
#   'label': 'Phosphorylation',
#   'documentId': '11815618',
#   'sentenceIndex': 4,
#   'words': ['TBK-1',
#    'and',
#    'IKK-i',
#    'phosphorylate',
#    'Ser(36',
#    ')',
#    'of',
#    'IkappaBalpha',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 3,
#     'end': 4,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 0, 'end': 1, 'namedCaptures': []}}]}]},
#  {'sentenceId': 100651,
#   'label': 'Phosphorylation',
#   'documentId': '9461591',
#   'sentenceIndex': 1,
#   'words': ['Platelet-activating',
#    'factor',
#    '(',
#    'PAF',
#    ')',
#    'is',
#    'a',
#    'potent',
#    'phospholipid',
#    'with',
#    'diverse',
#    'physiological',
#    'and',
#    'pathological',
#    'actions',
#    ',',
#    'and',
#    'it',
#    'is',
#    'inactivated',
#    'by',
#    'PAF',
#    'acetylhydrolase',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 8,
#     'end': 9,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 1, 'end': 2, 'namedCaptures': []}}]}]},
#  {'sentenceId': 69783,
#   'label': None,
#   'documentId': '10722751',
#   'sentenceIndex': 12,
#   'words': ['Their',
#    'major',
#    'lipid',
#    'constituents',
#    'were',
#    'phospholipids',
#    ',',
#    'unesterified',
#    'cholesterol',
#    ',',
#    'and',
#    'cholesteryl',
#    'esters',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 3, 'end': 4, 'namedCaptures': []}]},
#  {'sentenceId': 69783,
#   'label': 'Phosphorylation',
#   'documentId': '10722751',
#   'sentenceIndex': 12,
#   'words': ['Their',
#    'major',
#    'lipid',
#    'constituents',
#    'were',
#    'phospholipids',
#    ',',
#    'unesterified',
#    'cholesterol',
#    ',',
#    'and',
#    'cholesteryl',
#    'esters',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 5,
#     'end': 6,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 3, 'end': 4, 'namedCaptures': []}}]}]},
#  {'sentenceId': 181131,
#   'label': None,
#   'documentId': '11083482',
#   'sentenceIndex': 6,
#   'words': ['After',
#    'further',
#    'adjustment',
#    'for',
#    'other',
#    'significant',
#    'dietary',
#    'factors',
#    ',',
#    'the',
#    'only',
#    'significant',
#    'remaining',
#    'associations',
#    'observed',
#    'were',
#    'for',
#    'phosphorus',
#    'and',
#    'fat',
#    'at',
#    'the',
#    'lumbar',
#    'spine',
#    ',',
#    'although',
#    'the',
#    'adjusted',
#    'goodness',
#    'of',
#    'fit',
#    'of',
#    'the',
#    'models',
#    'improved',
#    'compared',
#    'to',
#    'those',
#    'including',
#    'one',
#    'dietary',
#    'variable',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 13, 'end': 14, 'namedCaptures': []}]},
#  {'sentenceId': 148291,
#   'label': None,
#   'documentId': '9546803',
#   'sentenceIndex': 4,
#   'words': ['At',
#    'the',
#    'cellular',
#    'level',
#    ',',
#    'the',
#    'main',
#    'problems',
#    'involved',
#    'in',
#    'the',
#    'use',
#    'of',
#    'such',
#    'drugs',
#    'are',
#    'their',
#    'limited',
#    'phosphorylation',
#    'in',
#    'some',
#    'cells',
#    '(',
#    'e.g.',
#    ',',
#    'antiretroviral',
#    'drugs',
#    'in',
#    'macrophages',
#    ')',
#    'and',
#    'the',
#    'cytotoxic',
#    'side',
#    'effects',
#    'of',
#    'nucleoside',
#    'analog',
#    'triphosphates',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 7, 'end': 8, 'namedCaptures': []}]},
#  {'sentenceId': 116105,
#   'label': None,
#   'documentId': '9186865',
#   'sentenceIndex': 1,
#   'words': ['Osteopontin',
#    'is',
#    'a',
#    'secreted',
#    ',',
#    'arginine-glycine-aspartate',
#    '(RGD)-containing',
#    'phosphoprotein',
#    'that',
#    'is',
#    'up-regulated',
#    'in',
#    'kidney',
#    'cortical',
#    'tubular',
#    'epithelial',
#    'cells',
#    'in',
#    'many',
#    'experimental',
#    'models',
#    'of',
#    'tubulointerstitial',
#    'fibrosis',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 0, 'end': 1, 'namedCaptures': []}]},
#  {'sentenceId': 148291,
#   'label': 'Phosphorylation',
#   'documentId': '9546803',
#   'sentenceIndex': 4,
#   'words': ['At',
#    'the',
#    'cellular',
#    'level',
#    ',',
#    'the',
#    'main',
#    'problems',
#    'involved',
#    'in',
#    'the',
#    'use',
#    'of',
#    'such',
#    'drugs',
#    'are',
#    'their',
#    'limited',
#    'phosphorylation',
#    'in',
#    'some',
#    'cells',
#    '(',
#    'e.g.',
#    ',',
#    'antiretroviral',
#    'drugs',
#    'in',
#    'macrophages',
#    ')',
#    'and',
#    'the',
#    'cytotoxic',
#    'side',
#    'effects',
#    'of',
#    'nucleoside',
#    'analog',
#    'triphosphates',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 18,
#     'end': 19,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 7, 'end': 8, 'namedCaptures': []}}]}]},
#  {'sentenceId': 181143,
#   'label': 'Phosphorylation',
#   'documentId': '9546680',
#   'sentenceIndex': 5,
#   'words': ['Since',
#    'phosphatidylethanolamine',
#    'is',
#    'a',
#    'dominant',
#    'phospholipid',
#    'in',
#    'Drosophila',
#    ',',
#    'these',
#    'changes',
#    'probably',
#    'contribute',
#    'to',
#    'keeping',
#    'the',
#    'homeoviscosity',
#    'of',
#    'the',
#    'cellular',
#    'membranes',
#    'in',
#    'a',
#    'manner',
#    'different',
#    'to',
#    'that',
#    'in',
#    'phosphatidylcholine-rich',
#    'membranes',
#    ',',
#    'thereby',
#    'increasing',
#    'cold',
#    'tolerance',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 5,
#     'end': 6,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 1, 'end': 2, 'namedCaptures': []}}]}]},
#  {'sentenceId': 181143,
#   'label': None,
#   'documentId': '9546680',
#   'sentenceIndex': 5,
#   'words': ['Since',
#    'phosphatidylethanolamine',
#    'is',
#    'a',
#    'dominant',
#    'phospholipid',
#    'in',
#    'Drosophila',
#    ',',
#    'these',
#    'changes',
#    'probably',
#    'contribute',
#    'to',
#    'keeping',
#    'the',
#    'homeoviscosity',
#    'of',
#    'the',
#    'cellular',
#    'membranes',
#    'in',
#    'a',
#    'manner',
#    'different',
#    'to',
#    'that',
#    'in',
#    'phosphatidylcholine-rich',
#    'membranes',
#    ',',
#    'thereby',
#    'increasing',
#    'cold',
#    'tolerance',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 1, 'end': 2, 'namedCaptures': []}]},
#  {'sentenceId': 116105,
#   'label': 'Phosphorylation',
#   'documentId': '9186865',
#   'sentenceIndex': 1,
#   'words': ['Osteopontin',
#    'is',
#    'a',
#    'secreted',
#    ',',
#    'arginine-glycine-aspartate',
#    '(RGD)-containing',
#    'phosphoprotein',
#    'that',
#    'is',
#    'up-regulated',
#    'in',
#    'kidney',
#    'cortical',
#    'tubular',
#    'epithelial',
#    'cells',
#    'in',
#    'many',
#    'experimental',
#    'models',
#    'of',
#    'tubulointerstitial',
#    'fibrosis',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 7,
#     'end': 8,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 0, 'end': 1, 'namedCaptures': []}}]}]},
#  {'sentenceId': 668183,
#   'label': 'Phosphorylation',
#   'documentId': '27488666',
#   'sentenceIndex': 1,
#   'words': ['Phosphatidylinositol-4,5-bisphosphate',
#    '(',
#    'PIP2',
#    ')',
#    'is',
#    'a',
#    'membrane',
#    'phosphoinositide',
#    'that',
#    'regulates',
#    'the',
#    'activity',
#    'of',
#    'many',
#    'ion',
#    'channels',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 7,
#     'end': 8,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 0, 'end': 1, 'namedCaptures': []}}]}]},
#  {'sentenceId': 76021,
#   'label': 'Phosphorylation',
#   'documentId': '27746179',
#   'sentenceIndex': 3,
#   'words': ['By',
#    'the',
#    'mass',
#    'spectrometry',
#    'analysis',
#    ',',
#    'we',
#    'demonstrate',
#    'that',
#    'Yor022c',
#    'is',
#    'actually',
#    'a',
#    'phospholipase',
#    'displaying',
#    'sn-1-specific',
#    'activity',
#    'toward',
#    'phosphatidylcholine',
#    ',',
#    'phosphatidylethanolamine',
#    ',',
#    'and',
#    'phosphatidic',
#    'acid',
#    ',',
#    'generating',
#    '2-acyl',
#    'lysophospholipids',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 13,
#     'end': 14,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 9, 'end': 10, 'namedCaptures': []}}]}]},
#  {'sentenceId': 76021,
#   'label': None,
#   'documentId': '27746179',
#   'sentenceIndex': 3,
#   'words': ['By',
#    'the',
#    'mass',
#    'spectrometry',
#    'analysis',
#    ',',
#    'we',
#    'demonstrate',
#    'that',
#    'Yor022c',
#    'is',
#    'actually',
#    'a',
#    'phospholipase',
#    'displaying',
#    'sn-1-specific',
#    'activity',
#    'toward',
#    'phosphatidylcholine',
#    ',',
#    'phosphatidylethanolamine',
#    ',',
#    'and',
#    'phosphatidic',
#    'acid',
#    ',',
#    'generating',
#    '2-acyl',
#    'lysophospholipids',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 9, 'end': 10, 'namedCaptures': []}]},
#  {'sentenceId': 466332,
#   'label': 'Phosphorylation',
#   'documentId': '27805608',
#   'sentenceIndex': 2,
#   'words': ['Phosphatidylinositol',
#    '4,5-bisphosphate',
#    '(',
#    'PI(4,5)P2',
#    ')',
#    'is',
#    'a',
#    'determinant',
#    'phosphoinositide',
#    'of',
#    'the',
#    'plasma',
#    'membrane',
#    '(',
#    'PM',
#    ')',
#    ',',
#    'and',
#    'it',
#    'is',
#    'required',
#    'to',
#    'modulate',
#    'ion',
#    'channels',
#    ',',
#    'actin',
#    'dynamics',
#    ',',
#    'exocytosis',
#    ',',
#    'endocytosis',
#    ',',
#    'intracellular',
#    'signaling',
#    ',',
#    'and',
#    'many',
#    'other',
#    'cellular',
#    'processes',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 8,
#     'end': 9,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 1, 'end': 2, 'namedCaptures': []}}]}]},
#  {'sentenceId': 349032,
#   'label': None,
#   'documentId': '27738977',
#   'sentenceIndex': 7,
#   'words': ['ORF3',
#    'protein',
#    'is',
#    'a',
#    'phosphoprotein',
#    'of',
#    '113',
#    'or',
#    '114',
#    'amino',
#    'acids',
#    'with',
#    'a',
#    'molecular',
#    'weight',
#    'of',
#    '13',
#    'kDa',
#    'with',
#    'multiple',
#    'functions',
#    'that',
#    'can',
#    'also',
#    'induce',
#    'strong',
#    'immune',
#    'reactivity',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 1, 'end': 2, 'namedCaptures': []}]},
#  {'sentenceId': 101964,
#   'label': 'Phosphorylation',
#   'documentId': '27518222',
#   'sentenceIndex': 2,
#   'words': ['Adenylate',
#    'kinase',
#    '(',
#    'ADK',
#    ')',
#    'is',
#    'a',
#    'phosphotransferase',
#    'that',
#    'plays',
#    'an',
#    'important',
#    'role',
#    'in',
#    'cellular',
#    'energy',
#    'homeostasis',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 7,
#     'end': 8,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 1, 'end': 2, 'namedCaptures': []}}]}]},
#  {'sentenceId': 466332,
#   'label': None,
#   'documentId': '27805608',
#   'sentenceIndex': 2,
#   'words': ['Phosphatidylinositol',
#    '4,5-bisphosphate',
#    '(',
#    'PI(4,5)P2',
#    ')',
#    'is',
#    'a',
#    'determinant',
#    'phosphoinositide',
#    'of',
#    'the',
#    'plasma',
#    'membrane',
#    '(',
#    'PM',
#    ')',
#    ',',
#    'and',
#    'it',
#    'is',
#    'required',
#    'to',
#    'modulate',
#    'ion',
#    'channels',
#    ',',
#    'actin',
#    'dynamics',
#    ',',
#    'exocytosis',
#    ',',
#    'endocytosis',
#    ',',
#    'intracellular',
#    'signaling',
#    ',',
#    'and',
#    'many',
#    'other',
#    'cellular',
#    'processes',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 1, 'end': 2, 'namedCaptures': []}]},
#  {'sentenceId': 594890,
#   'label': 'Phosphorylation',
#   'documentId': '27566835',
#   'sentenceIndex': 11,
#   'words': ['Mineral',
#    'metabolism',
#    'factors',
#    'predicting',
#    'accelerated',
#    'progression',
#    'were',
#    'serum',
#    'phosphorus',
#    'in',
#    'stages',
#    '3',
#    'and',
#    '5D',
#    ';',
#    'low',
#    '25-hydroxyvitamin',
#    'D',
#    'and',
#    'parathyroid',
#    'hormone',
#    'levels',
#    '>',
#    '110',
#    'pg/mL',
#    'in',
#    'stages',
#    '4',
#    '-',
#    '5',
#    'and',
#    'intact',
#    'parathyroid',
#    'hormone',
#    'levels',
#    'out',
#    'of',
#    'the',
#    'recommended',
#    'range',
#    'in',
#    'stage',
#    '5D',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 8,
#     'end': 9,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 2, 'end': 3, 'namedCaptures': []}}]}]},
#  {'sentenceId': 546070,
#   'label': 'Phosphorylation',
#   'documentId': '27614627',
#   'sentenceIndex': 1,
#   'words': ['Dmp1',
#    'is',
#    'an',
#    'acidic',
#    'phosphoprotein',
#    'that',
#    'is',
#    'specifically',
#    'expressed',
#    'in',
#    'osteocytes',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 4,
#     'end': 5,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 0, 'end': 1, 'namedCaptures': []}}]}]},
#  {'sentenceId': 546070,
#   'label': None,
#   'documentId': '27614627',
#   'sentenceIndex': 1,
#   'words': ['Dmp1',
#    'is',
#    'an',
#    'acidic',
#    'phosphoprotein',
#    'that',
#    'is',
#    'specifically',
#    'expressed',
#    'in',
#    'osteocytes',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 0, 'end': 1, 'namedCaptures': []}]},
#  {'sentenceId': 592456,
#   'label': 'Phosphorylation',
#   'documentId': '27502175',
#   'sentenceIndex': 5,
#   'words': ['The',
#    'major',
#    'polar',
#    'lipids',
#    'were',
#    'phosphoglycolipids',
#    'and',
#    'phospholipids',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 5,
#     'end': 6,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 3, 'end': 4, 'namedCaptures': []}}]}]},
#  {'sentenceId': 668183,
#   'label': None,
#   'documentId': '27488666',
#   'sentenceIndex': 1,
#   'words': ['Phosphatidylinositol-4,5-bisphosphate',
#    '(',
#    'PIP2',
#    ')',
#    'is',
#    'a',
#    'membrane',
#    'phosphoinositide',
#    'that',
#    'regulates',
#    'the',
#    'activity',
#    'of',
#    'many',
#    'ion',
#    'channels',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 0, 'end': 1, 'namedCaptures': []}]},
#  {'sentenceId': 374130,
#   'label': 'Phosphorylation',
#   'documentId': '27735865',
#   'sentenceIndex': 4,
#   'words': ['Activation',
#    'of',
#    'NF-B',
#    ',',
#    'extracellular',
#    'signal-regulated',
#    'kinase',
#    '(',
#    'ERK',
#    ')',
#    'phosphorylates',
#    ',',
#    'and',
#    'calcium',
#    'oscillation',
#    'signaling',
#    'pathways',
#    'by',
#    'receptor',
#    'activator',
#    'NF-B',
#    'ligand',
#    '(',
#    'RANKL',
#    ')',
#    'plays',
#    'a',
#    'pivotal',
#    'role',
#    'in',
#    'osteoclast',
#    'activation',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 10,
#     'end': 11,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 0, 'end': 1, 'namedCaptures': []}}]}]},
#  {'sentenceId': 374130,
#   'label': None,
#   'documentId': '27735865',
#   'sentenceIndex': 4,
#   'words': ['Activation',
#    'of',
#    'NF-B',
#    ',',
#    'extracellular',
#    'signal-regulated',
#    'kinase',
#    '(',
#    'ERK',
#    ')',
#    'phosphorylates',
#    ',',
#    'and',
#    'calcium',
#    'oscillation',
#    'signaling',
#    'pathways',
#    'by',
#    'receptor',
#    'activator',
#    'NF-B',
#    'ligand',
#    '(',
#    'RANKL',
#    ')',
#    'plays',
#    'a',
#    'pivotal',
#    'role',
#    'in',
#    'osteoclast',
#    'activation',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 0, 'end': 1, 'namedCaptures': []}]},
#  {'sentenceId': 101964,
#   'label': None,
#   'documentId': '27518222',
#   'sentenceIndex': 2,
#   'words': ['Adenylate',
#    'kinase',
#    '(',
#    'ADK',
#    ')',
#    'is',
#    'a',
#    'phosphotransferase',
#    'that',
#    'plays',
#    'an',
#    'important',
#    'role',
#    'in',
#    'cellular',
#    'energy',
#    'homeostasis',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 1, 'end': 2, 'namedCaptures': []}]},
#  {'sentenceId': 156449,
#   'label': None,
#   'documentId': '27519475',
#   'sentenceIndex': 3,
#   'words': ['In',
#    'this',
#    'study',
#    ',',
#    'the',
#    'use',
#    'of',
#    'a',
#    'combined',
#    'pharmacological',
#    'and',
#    'genetic',
#    'approach',
#    'identified',
#    'Lck',
#    ',',
#    'a',
#    'Src',
#    'family',
#    'member',
#    ',',
#    'as',
#    'the',
#    'tyrosine',
#    'kinase',
#    'phosphorylating',
#    'PLC',
#    'leading',
#    'to',
#    'Rac1',
#    'and',
#    'PYGM',
#    'activation',
#    'in',
#    'the',
#    'IL-2-stimulated',
#    'Kit',
#    '225',
#    'T',
#    'cells',
#    'via',
#    'the',
#    'PKC/PIX',
#    'pathway',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 24, 'end': 25, 'namedCaptures': []}]},
#  {'sentenceId': 156449,
#   'label': 'Phosphorylation',
#   'documentId': '27519475',
#   'sentenceIndex': 3,
#   'words': ['In',
#    'this',
#    'study',
#    ',',
#    'the',
#    'use',
#    'of',
#    'a',
#    'combined',
#    'pharmacological',
#    'and',
#    'genetic',
#    'approach',
#    'identified',
#    'Lck',
#    ',',
#    'a',
#    'Src',
#    'family',
#    'member',
#    ',',
#    'as',
#    'the',
#    'tyrosine',
#    'kinase',
#    'phosphorylating',
#    'PLC',
#    'leading',
#    'to',
#    'Rac1',
#    'and',
#    'PYGM',
#    'activation',
#    'in',
#    'the',
#    'IL-2-stimulated',
#    'Kit',
#    '225',
#    'T',
#    'cells',
#    'via',
#    'the',
#    'PKC/PIX',
#    'pathway',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 25,
#     'end': 26,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 24, 'end': 25, 'namedCaptures': []}}]}]},
#  {'sentenceId': 594890,
#   'label': None,
#   'documentId': '27566835',
#   'sentenceIndex': 11,
#   'words': ['Mineral',
#    'metabolism',
#    'factors',
#    'predicting',
#    'accelerated',
#    'progression',
#    'were',
#    'serum',
#    'phosphorus',
#    'in',
#    'stages',
#    '3',
#    'and',
#    '5D',
#    ';',
#    'low',
#    '25-hydroxyvitamin',
#    'D',
#    'and',
#    'parathyroid',
#    'hormone',
#    'levels',
#    '>',
#    '110',
#    'pg/mL',
#    'in',
#    'stages',
#    '4',
#    '-',
#    '5',
#    'and',
#    'intact',
#    'parathyroid',
#    'hormone',
#    'levels',
#    'out',
#    'of',
#    'the',
#    'recommended',
#    'range',
#    'in',
#    'stage',
#    '5D',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 2, 'end': 3, 'namedCaptures': []}]},
#  {'sentenceId': 349032,
#   'label': 'Phosphorylation',
#   'documentId': '27738977',
#   'sentenceIndex': 7,
#   'words': ['ORF3',
#    'protein',
#    'is',
#    'a',
#    'phosphoprotein',
#    'of',
#    '113',
#    'or',
#    '114',
#    'amino',
#    'acids',
#    'with',
#    'a',
#    'molecular',
#    'weight',
#    'of',
#    '13',
#    'kDa',
#    'with',
#    'multiple',
#    'functions',
#    'that',
#    'can',
#    'also',
#    'induce',
#    'strong',
#    'immune',
#    'reactivity',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 4,
#     'end': 5,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 1, 'end': 2, 'namedCaptures': []}}]}]},
#  {'sentenceId': 592456,
#   'label': None,
#   'documentId': '27502175',
#   'sentenceIndex': 5,
#   'words': ['The',
#    'major',
#    'polar',
#    'lipids',
#    'were',
#    'phosphoglycolipids',
#    'and',
#    'phospholipids',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 3, 'end': 4, 'namedCaptures': []}]},
#  {'sentenceId': 425642,
#   'label': 'Phosphorylation',
#   'documentId': '30854842',
#   'sentenceIndex': 2,
#   'words': ['Both',
#    'Pd1',
#    'and',
#    'Pd2',
#    'are',
#    'rare',
#    'bright',
#    'deep',
#    'blue',
#    'Pd(II',
#    ')',
#    'phosphors',
#    'with',
#    'contrasting',
#    'properties',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 11,
#     'end': 12,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 9, 'end': 10, 'namedCaptures': []}}]}]},
#  {'sentenceId': 826867,
#   'label': None,
#   'documentId': '29580751',
#   'sentenceIndex': 3,
#   'words': ['The',
#    'CRC',
#    'condition',
#    'was',
#    'produced',
#    'in',
#    'response',
#    'to',
#    'COX-2',
#    'and',
#    'IL-6',
#    'induced',
#    'activation',
#    'of',
#    'JAK2/STAT3',
#    'which',
#    ',',
#    'in',
#    'turn',
#    ',',
#    'was',
#    'due',
#    'to',
#    'the',
#    'enhanced',
#    'phosphorylation',
#    'of',
#    'JAK2',
#    'and',
#    'STAT3',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 15, 'end': 16, 'namedCaptures': []}]},
#  {'sentenceId': 172389,
#   'label': 'Phosphorylation',
#   'documentId': '30857749',
#   'sentenceIndex': 1,
#   'words': ['A',
#    'series',
#    'of',
#    'N-alkoxy',
#    'analogs',
#    'of',
#    'a',
#    'l-leucine',
#    'ethyl',
#    'ester',
#    'phosphonodiamidate',
#    'prodrug',
#    'of',
#    'a',
#    'fosmidomycin',
#    'surrogate',
#    'were',
#    'synthesized',
#    'and',
#    'investigated',
#    'for',
#    'their',
#    'ability',
#    'to',
#    'inhibit',
#    'in',
#    'vitro',
#    'growth',
#    'of',
#    'P.',
#    'falciparum',
#    'and',
#    'M.',
#    'tuberculosis',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 10,
#     'end': 11,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 1, 'end': 2, 'namedCaptures': []}}]}]},
#  {'sentenceId': 1073498,
#   'label': None,
#   'documentId': '30847983',
#   'sentenceIndex': 1,
#   'words': ['BACKGROUND',
#    'LPA',
#    'is',
#    'a',
#    'small',
#    'bioactive',
#    'phospholipid',
#    'that',
#    'acts',
#    'as',
#    'an',
#    'extracellular',
#    'signaling',
#    'molecule',
#    'and',
#    'is',
#    'involved',
#    'in',
#    'cellular',
#    'processes',
#    ',',
#    'including',
#    'cell',
#    'proliferation',
#    ',',
#    'migration',
#    ',',
#    'and',
#    'differentiation',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 1, 'end': 2, 'namedCaptures': []}]},
#  {'sentenceId': 804683,
#   'label': 'Phosphorylation',
#   'documentId': '30279506',
#   'sentenceIndex': 5,
#   'words': ['Fifteen',
#    'potential',
#    'biomarkers',
#    'were',
#    'identified',
#    'and',
#    'these',
#    'biomarkers',
#    'are',
#    'mainly',
#    'phospholipids',
#    'and',
#    'fatty',
#    'acids',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 10,
#     'end': 11,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 7, 'end': 8, 'namedCaptures': []}}]}]},
#  {'sentenceId': 780988,
#   'label': None,
#   'documentId': '30279533',
#   'sentenceIndex': 3,
#   'words': ['Here',
#    ',',
#    'we',
#    'report',
#    'the',
#    'results',
#    'of',
#    'our',
#    'molecular',
#    'dynamics',
#    'studies',
#    'on',
#    'the',
#    'mechanism',
#    'by',
#    'which',
#    'posttranslational',
#    'modifications',
#    ',',
#    'in',
#    'particular',
#    'the',
#    'phosphorylation',
#    'of',
#    'three',
#    'serine',
#    'residues',
#    '(',
#    'Ser-264-',
#    ',',
#    'Ser-271-',
#    ',',
#    'and',
#    'Ser-203-',
#    ')',
#    ',',
#    'influence',
#    'the',
#    'enzymatic',
#    'function',
#    'of',
#    'the',
#    'protein',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 17, 'end': 18, 'namedCaptures': []}]},
#  {'sentenceId': 1073498,
#   'label': 'Phosphorylation',
#   'documentId': '30847983',
#   'sentenceIndex': 1,
#   'words': ['BACKGROUND',
#    'LPA',
#    'is',
#    'a',
#    'small',
#    'bioactive',
#    'phospholipid',
#    'that',
#    'acts',
#    'as',
#    'an',
#    'extracellular',
#    'signaling',
#    'molecule',
#    'and',
#    'is',
#    'involved',
#    'in',
#    'cellular',
#    'processes',
#    ',',
#    'including',
#    'cell',
#    'proliferation',
#    ',',
#    'migration',
#    ',',
#    'and',
#    'differentiation',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 6,
#     'end': 7,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 1, 'end': 2, 'namedCaptures': []}}]}]},
#  {'sentenceId': 172389,
#   'label': None,
#   'documentId': '30857749',
#   'sentenceIndex': 1,
#   'words': ['A',
#    'series',
#    'of',
#    'N-alkoxy',
#    'analogs',
#    'of',
#    'a',
#    'l-leucine',
#    'ethyl',
#    'ester',
#    'phosphonodiamidate',
#    'prodrug',
#    'of',
#    'a',
#    'fosmidomycin',
#    'surrogate',
#    'were',
#    'synthesized',
#    'and',
#    'investigated',
#    'for',
#    'their',
#    'ability',
#    'to',
#    'inhibit',
#    'in',
#    'vitro',
#    'growth',
#    'of',
#    'P.',
#    'falciparum',
#    'and',
#    'M.',
#    'tuberculosis',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 1, 'end': 2, 'namedCaptures': []}]},
#  {'sentenceId': 804683,
#   'label': None,
#   'documentId': '30279506',
#   'sentenceIndex': 5,
#   'words': ['Fifteen',
#    'potential',
#    'biomarkers',
#    'were',
#    'identified',
#    'and',
#    'these',
#    'biomarkers',
#    'are',
#    'mainly',
#    'phospholipids',
#    'and',
#    'fatty',
#    'acids',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 7, 'end': 8, 'namedCaptures': []}]},
#  {'sentenceId': 1287522,
#   'label': 'Phosphorylation',
#   'documentId': '30658116',
#   'sentenceIndex': 2,
#   'words': ['Lysophosphatidic',
#    'acid',
#    '(',
#    'LPA',
#    ')',
#    'is',
#    'a',
#    'phospholipid',
#    'that',
#    'contracts',
#    'the',
#    'urethra',
#    'by',
#    'activating',
#    'type',
#    '1',
#    'LPA',
#    'receptors',
#    '(',
#    'LPA1',
#    ')',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 7,
#     'end': 8,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 1, 'end': 2, 'namedCaptures': []}}]}]},
#  {'sentenceId': 216666,
#   'label': 'Phosphorylation',
#   'documentId': '30858140',
#   'sentenceIndex': 1,
#   'words': ['Synapsins',
#    'are',
#    'neuronal',
#    'phosphoproteins',
#    'that',
#    'fine-tune',
#    'synaptic',
#    'transmission',
#    'and',
#    'suppress',
#    'seizure',
#    'activity',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 3,
#     'end': 4,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 0, 'end': 1, 'namedCaptures': []}}]}]},
#  {'sentenceId': 747392,
#   'label': None,
#   'documentId': '29743582',
#   'sentenceIndex': 1,
#   'words': ['Lysophosphatidic',
#    'acid',
#    '(',
#    'LPA',
#    ')',
#    'is',
#    'a',
#    'synaptic',
#    'phospholipid',
#    ',',
#    'which',
#    'regulates',
#    'cortical',
#    'excitation/inhibition',
#    '(',
#    'E/I',
#    ')',
#    'balance',
#    'and',
#    'controls',
#    'sensory',
#    'information',
#    'processing',
#    'in',
#    'mice',
#    'and',
#    'man',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 1, 'end': 2, 'namedCaptures': []}]},
#  {'sentenceId': 780988,
#   'label': 'Phosphorylation',
#   'documentId': '30279533',
#   'sentenceIndex': 3,
#   'words': ['Here',
#    ',',
#    'we',
#    'report',
#    'the',
#    'results',
#    'of',
#    'our',
#    'molecular',
#    'dynamics',
#    'studies',
#    'on',
#    'the',
#    'mechanism',
#    'by',
#    'which',
#    'posttranslational',
#    'modifications',
#    ',',
#    'in',
#    'particular',
#    'the',
#    'phosphorylation',
#    'of',
#    'three',
#    'serine',
#    'residues',
#    '(',
#    'Ser-264-',
#    ',',
#    'Ser-271-',
#    ',',
#    'and',
#    'Ser-203-',
#    ')',
#    ',',
#    'influence',
#    'the',
#    'enzymatic',
#    'function',
#    'of',
#    'the',
#    'protein',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 22,
#     'end': 23,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 17, 'end': 18, 'namedCaptures': []}}]}]},
#  {'sentenceId': 1212969,
#   'label': None,
#   'documentId': '30346938',
#   'sentenceIndex': 6,
#   'words': ['We',
#    'also',
#    'fluorescently',
#    'labeled',
#    'phosphoserines',
#    'and',
#    'achieved',
#    'single-molecule',
#    'positional',
#    'readout',
#    'of',
#    'the',
#    'phosphorylated',
#    'sites',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 0, 'end': 1, 'namedCaptures': []}]},
#  {'sentenceId': 425642,
#   'label': None,
#   'documentId': '30854842',
#   'sentenceIndex': 2,
#   'words': ['Both',
#    'Pd1',
#    'and',
#    'Pd2',
#    'are',
#    'rare',
#    'bright',
#    'deep',
#    'blue',
#    'Pd(II',
#    ')',
#    'phosphors',
#    'with',
#    'contrasting',
#    'properties',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 9, 'end': 10, 'namedCaptures': []}]},
#  {'sentenceId': 747392,
#   'label': 'Phosphorylation',
#   'documentId': '29743582',
#   'sentenceIndex': 1,
#   'words': ['Lysophosphatidic',
#    'acid',
#    '(',
#    'LPA',
#    ')',
#    'is',
#    'a',
#    'synaptic',
#    'phospholipid',
#    ',',
#    'which',
#    'regulates',
#    'cortical',
#    'excitation/inhibition',
#    '(',
#    'E/I',
#    ')',
#    'balance',
#    'and',
#    'controls',
#    'sensory',
#    'information',
#    'processing',
#    'in',
#    'mice',
#    'and',
#    'man',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 8,
#     'end': 9,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 1, 'end': 2, 'namedCaptures': []}}]}]},
#  {'sentenceId': 1212969,
#   'label': 'Phosphorylation',
#   'documentId': '30346938',
#   'sentenceIndex': 6,
#   'words': ['We',
#    'also',
#    'fluorescently',
#    'labeled',
#    'phosphoserines',
#    'and',
#    'achieved',
#    'single-molecule',
#    'positional',
#    'readout',
#    'of',
#    'the',
#    'phosphorylated',
#    'sites',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 4,
#     'end': 5,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 0, 'end': 1, 'namedCaptures': []}}]}]},
#  {'sentenceId': 216666,
#   'label': None,
#   'documentId': '30858140',
#   'sentenceIndex': 1,
#   'words': ['Synapsins',
#    'are',
#    'neuronal',
#    'phosphoproteins',
#    'that',
#    'fine-tune',
#    'synaptic',
#    'transmission',
#    'and',
#    'suppress',
#    'seizure',
#    'activity',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 0, 'end': 1, 'namedCaptures': []}]},
#  {'sentenceId': 1287522,
#   'label': None,
#   'documentId': '30658116',
#   'sentenceIndex': 2,
#   'words': ['Lysophosphatidic',
#    'acid',
#    '(',
#    'LPA',
#    ')',
#    'is',
#    'a',
#    'phospholipid',
#    'that',
#    'contracts',
#    'the',
#    'urethra',
#    'by',
#    'activating',
#    'type',
#    '1',
#    'LPA',
#    'receptors',
#    '(',
#    'LPA1',
#    ')',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 1, 'end': 2, 'namedCaptures': []}]},
#  {'sentenceId': 826867,
#   'label': 'Phosphorylation',
#   'documentId': '29580751',
#   'sentenceIndex': 3,
#   'words': ['The',
#    'CRC',
#    'condition',
#    'was',
#    'produced',
#    'in',
#    'response',
#    'to',
#    'COX-2',
#    'and',
#    'IL-6',
#    'induced',
#    'activation',
#    'of',
#    'JAK2/STAT3',
#    'which',
#    ',',
#    'in',
#    'turn',
#    ',',
#    'was',
#    'due',
#    'to',
#    'the',
#    'enhanced',
#    'phosphorylation',
#    'of',
#    'JAK2',
#    'and',
#    'STAT3',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 25,
#     'end': 26,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 15, 'end': 16, 'namedCaptures': []}}]}]},
#  {'sentenceId': 52426,
#   'label': None,
#   'documentId': '18179840',
#   'sentenceIndex': 1,
#   'words': ['Human',
#    'respiratory',
#    'syncytial',
#    'virus',
#    '(',
#    'HRSV',
#    ')',
#    'P',
#    'protein',
#    ',',
#    '241',
#    'amino',
#    'acid',
#    'long',
#    ',',
#    'is',
#    'a',
#    'structural',
#    'homotetrameric',
#    'phosphoprotein',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 8, 'end': 9, 'namedCaptures': []}]},
#  {'sentenceId': 112202,
#   'label': 'Phosphorylation',
#   'documentId': '16842388',
#   'sentenceIndex': 1,
#   'words': ['Cilomilast',
#    '(',
#    'Ariflo',
#    ',',
#    'SB',
#    '207499',
#    ')',
#    'is',
#    'an',
#    'orally',
#    'active',
#    ',',
#    'second-generation',
#    'phosphodiesterase',
#    '(',
#    'PDE',
#    ')',
#    '4',
#    'inhibitor',
#    'that',
#    'is',
#    'being',
#    'developed',
#    'by',
#    'GlaxoSmithkline',
#    'for',
#    'the',
#    'treatment',
#    'of',
#    'chronic',
#    'obstructive',
#    'pulmonary',
#    'disease',
#    '(',
#    'COPD',
#    ')',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 13,
#     'end': 14,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 0, 'end': 1, 'namedCaptures': []}}]}]},
#  {'sentenceId': 112202,
#   'label': None,
#   'documentId': '16842388',
#   'sentenceIndex': 1,
#   'words': ['Cilomilast',
#    '(',
#    'Ariflo',
#    ',',
#    'SB',
#    '207499',
#    ')',
#    'is',
#    'an',
#    'orally',
#    'active',
#    ',',
#    'second-generation',
#    'phosphodiesterase',
#    '(',
#    'PDE',
#    ')',
#    '4',
#    'inhibitor',
#    'that',
#    'is',
#    'being',
#    'developed',
#    'by',
#    'GlaxoSmithkline',
#    'for',
#    'the',
#    'treatment',
#    'of',
#    'chronic',
#    'obstructive',
# ...
#    'by',
#    'securin',
#    ',',
#    'and',
#    'another',
#    'is',
#    'phosphorylation',
#    'on',
#    'Ser1126',
#    '(',
#    'in',
#    'humans',
#    '[',
#    'Ser1121',
#    'in',
#    'mice',
#    ']',
#    ')',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 11, 'end': 12, 'namedCaptures': []}]},
#  {'sentenceId': 105952,
#   'label': None,
#   'documentId': '20674860',
#   'sentenceIndex': 2,
#   'words': ['Cardiolipin',
#    '(',
#    'CL',
#    ')',
#    'is',
#    'a',
#    'key',
#    'mitochondrial',
#    'phospholipid',
#    'required',
#    'for',
#    'oxidative',
#    'phosphorylation',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 0, 'end': 1, 'namedCaptures': []}]},
#  {'sentenceId': 189275,
#   'label': 'Phosphorylation',
#   'documentId': '21373727',
#   'sentenceIndex': 2,
#   'words': ['It',
#    'is',
#    'an',
#    'acyclic',
#    'nucleoside',
#    'phosphonate',
#    'that',
#    'is',
#    'relatively',
#    'safe',
#    'in',
#    'the',
#    'dosage',
#    'generally',
#    'used',
#    'for',
#    'chronic',
#    'hepatitis',
#    'B.',
#    'Serious',
#    'adverse',
#    'cutaneous',
#    'drug',
#    'reactions',
#    'like',
#    'Stevens-Johnson',
#    'syndrome',
#    '(',
#    'SJS',
#    ')',
#    'or',
#    'toxic',
#    'epidermal',
#    'necrolysis',
#    '(',
#    'TEN',
#    ')',
#    'following',
#    'adefovir',
#    'use',
#    'have',
#    'not',
#    'been',
#    'reported',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 5,
#     'end': 6,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 0, 'end': 1, 'namedCaptures': []}}]}]},
#  {'sentenceId': 93541,
#   'label': None,
#   'documentId': '19523343',
#   'sentenceIndex': 6,
#   'words': ['This',
#    'enzyme',
#    'phosphorylates',
#    'and',
#    'inhibits',
#    'nuclear',
#    'factors',
#    'that',
#    'turn',
#    'on',
#    'cell',
#    'growth',
#    'and',
#    'protection',
#    'programs',
#    ',',
#    'including',
#    'the',
#    'nuclear',
#    'factor',
#    'of',
#    'activated',
#    'T',
#    'cells',
#    '(',
#    'NFAT',
#    ')',
#    'and',
#    'WNT/beta-catenin',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 1, 'end': 2, 'namedCaptures': []}]},
#  {'sentenceId': 118503,
#   'label': None,
#   'documentId': '19423865',
#   'sentenceIndex': 1,
#   'words': ['OBJECTIVE',
#    'Sphingosine-1-phosphate',
#    '(',
#    'S1P',
#    ')',
#    'is',
#    'a',
#    'potent',
#    'bioactive',
#    'phospholipid',
#    'responsible',
#    'for',
#    'a',
#    'variety',
#    'of',
#    'vascular',
#    'cell',
#    'responses',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 1, 'end': 2, 'namedCaptures': []}]},
#  {'sentenceId': 86773,
#   'label': 'Phosphorylation',
#   'documentId': '19423373',
#   'sentenceIndex': 1,
#   'words': ['Lysophosphatidic',
#    'acid',
#    '(',
#    'LPA',
#    ')',
#    'is',
#    'a',
#    'naturally',
#    'occurring',
#    'phospholipid',
#    'that',
#    'initiates',
#    'a',
#    'broad',
#    'array',
#    'of',
#    'biological',
#    'processes',
#    ',',
#    'including',
#    'those',
#    'involved',
#    'in',
#    'cell',
#    'proliferation',
#    ',',
#    'survival',
#    'and',
#    'migration',
#    'via',
#    'activation',
#    'of',
#    'specific',
#    'G',
#    'protein-coupled',
#    'receptors',
#    'located',
#    'on',
#    'the',
#    'cell',
#    'surface',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 9,
#     'end': 10,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 1, 'end': 2, 'namedCaptures': []}}]}]},
#  {'sentenceId': 47395,
#   'label': 'Phosphorylation',
#   'documentId': '19124608',
#   'sentenceIndex': 4,
#   'words': ['One',
#    'mechanism',
#    'is',
#    'through',
#    'binding',
#    'and',
#    'inhibition',
#    'by',
#    'securin',
#    ',',
#    'and',
#    'another',
#    'is',
#    'phosphorylation',
#    'on',
#    'Ser1126',
#    '(',
#    'in',
#    'humans',
#    '[',
#    'Ser1121',
#    'in',
#    'mice',
#    ']',
#    ')',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 13,
#     'end': 14,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 11, 'end': 12, 'namedCaptures': []}}]}]},
#  {'sentenceId': 105952,
#   'label': 'Phosphorylation',
#   'documentId': '20674860',
#   'sentenceIndex': 2,
#   'words': ['Cardiolipin',
#    '(',
#    'CL',
#    ')',
#    'is',
#    'a',
#    'key',
#    'mitochondrial',
#    'phospholipid',
#    'required',
#    'for',
#    'oxidative',
#    'phosphorylation',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 8,
#     'end': 9,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 0, 'end': 1, 'namedCaptures': []}}]}]},
#  {'sentenceId': 205977,
#   'label': 'Phosphorylation',
#   'documentId': '24616519',
#   'sentenceIndex': 1,
#   'words': ['Nucleophosmin',
#    '(',
#    'NPM1',
#    ')',
#    'is',
#    'a',
#    'multifunctional',
#    'phospho-protein',
#    'with',
#    'critical',
#    'roles',
#    'in',
#    'ribosome',
#    'biogenesis',
#    ',',
#    'tumor',
#    'suppression',
#    ',',
#    'and',
#    'nucleolar',
#    'stress',
#    'response',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 7,
#     'end': 8,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 0, 'end': 1, 'namedCaptures': []}}]}]},
#  {'sentenceId': 351648,
#   'label': None,
#   'documentId': '21957203',
#   'sentenceIndex': 1,
#   'words': ['Cardiolipin',
#    '(',
#    'CL',
#    ')',
#    'is',
#    'a',
#    'unique',
#    'phospholipid',
#    '(',
#    'PL',
#    ')',
#    'found',
#    'in',
#    'the',
#    'mitochondria',
#    'of',
#    'mammalian',
#    'cells',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 0, 'end': 1, 'namedCaptures': []}]},
#  {'sentenceId': 8139,
#   'label': None,
#   'documentId': '21751345',
#   'sentenceIndex': 5,
#   'words': ['These',
#    'proteins',
#    'were',
#    ':',
#    'phosphoglucomutase',
#    ',',
#    'phosphoglucose',
#    'isomerase',
#    ',',
#    'S-adenosyl',
#    'methionine-dependent',
#    'methyltransferase',
#    'class',
#    'I',
#    ',',
#    'aldehyde',
#    'dehydrogenase',
#    ',',
#    'catalase',
#    ',',
#    '6-phosphogluconate',
#    'dehydrogenase',
#    ',',
#    'fumarylacetoacetate',
#    'hydrolase',
#    ',',
#    '4-hydroxyphenylpyruvic',
#    'dioxygenase',
#    ',',
#    'methylmalonate-semialdehyde',
#    'dehydrogenase',
#    ',',
#    'lysozyme',
#    ',',
#    'urate',
#    'oxidase',
#    ',',
#    'elongation',
#    'factor',
#    '2',
#    ',',
#    '60kDa',
#    'heat-shock',
#    'protein',
#    ',',
#    '58kDa',
#    'glucose-regulated',
#    'protein',
#    ',',
#    'cytokeratin',
#    'E7',
#    ',',
#    'type-II',
#    'keratin',
#    ',',
#    'intermediate',
#    'filament',
#    'proteins',
#    ',',
#    '17',
#    '-',
#    '-hydroxysteroid',
#    'dehydrogenase',
#    'type',
#    '4',
#    ',',
#    'and',
#    'kinase',
#    'suppressor',
#    'of',
#    'Ras1',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 1, 'end': 2, 'namedCaptures': []}]},
#  {'sentenceId': 454396,
#   'label': 'Phosphorylation',
#   'documentId': '22354989',
#   'sentenceIndex': 5,
#   'words': ['We',
#    'propose',
#    'a',
#    'model',
#    'in',
#    'which',
#    'the',
#    'initiating',
#    'event',
#    'for',
#    'Gwl',
#    'activation',
#    'is',
#    'phosphorylation',
#    'by',
#    'MPF',
#    'of',
#    'the',
#    'proline-directed',
#    'sites',
#    'T193',
#    'and',
#    'T206',
#    'in',
#    'the',
#    'presumptive',
#    'activation',
#    'loop',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 13,
#     'end': 14,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 8, 'end': 9, 'namedCaptures': []}}]}]},
#  {'sentenceId': 237195,
#   'label': 'Phosphorylation',
#   'documentId': '21803082',
#   'sentenceIndex': 2,
#   'words': ['A',
#    'promising',
#    'enzyme',
#    'is',
#    'cellobiose',
#    'phosphorylase',
#    '(',
#    'CP',
#    ')',
#    ',',
#    'which',
#    'was',
#    'discovered',
#    'more',
#    'than',
#    '50',
#    'years',
#    'ago',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 5,
#     'end': 6,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 2, 'end': 3, 'namedCaptures': []}}]}]},
#  {'sentenceId': 7764,
#   'label': 'Phosphorylation',
#   'documentId': '22162980',
#   'sentenceIndex': 2,
#   'words': ['LPA',
#    'is',
#    'a',
#    'bioactive',
#    'phospholipid',
#    'produced',
#    'by',
#    'activated',
#    'platelets',
#    'and',
#    'formed',
#    'during',
#    'the',
#    'oxidation',
#    'of',
#    'LDL',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 4,
#     'end': 5,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 0, 'end': 1, 'namedCaptures': []}}]}]},
#  {'sentenceId': 304088,
#   'label': None,
#   'documentId': '23849346',
#   'sentenceIndex': 4,
#   'words': ['The',
#    'emission',
#    'was',
#    'phosphorescence',
#    'in',
#    'nature',
#    'and',
#    'can',
#    'be',
#    'quenched',
#    'by',
#    'O2',
#    'with',
#    'the',
#    'generation',
#    'of',
#    'singlet',
#    'oxygen',
#    '(',
#    '(1)O2',
#    ')',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 1, 'end': 2, 'namedCaptures': []}]},
#  {'sentenceId': 237195,
#   'label': None,
#   'documentId': '21803082',
#   'sentenceIndex': 2,
#   'words': ['A',
#    'promising',
#    'enzyme',
#    'is',
#    'cellobiose',
#    'phosphorylase',
#    '(',
#    'CP',
#    ')',
#    ',',
#    'which',
#    'was',
#    'discovered',
#    'more',
#    'than',
#    '50',
#    'years',
#    'ago',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 2, 'end': 3, 'namedCaptures': []}]},
#  {'sentenceId': 469952,
#   'label': None,
#   'documentId': '22154263',
#   'sentenceIndex': 9,
#   'words': ['All',
#    'the',
#    'spectrum',
#    'features',
#    'indicate',
#    'that',
#    'Ca(9)Y(PO(4))(7):Eu(3',
#    '+',
#    ')',
#    'might',
#    'be',
#    'a',
#    'promising',
#    'phosphor',
#    'for',
#    'display',
#    'devices',
#    'or',
#    'w-LEDs',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 6, 'end': 7, 'namedCaptures': []}]},
#  {'sentenceId': 304088,
#   'label': 'Phosphorylation',
#   'documentId': '23849346',
#   'sentenceIndex': 4,
#   'words': ['The',
#    'emission',
#    'was',
#    'phosphorescence',
#    'in',
#    'nature',
#    'and',
#    'can',
#    'be',
#    'quenched',
#    'by',
#    'O2',
#    'with',
#    'the',
#    'generation',
#    'of',
#    'singlet',
#    'oxygen',
#    '(',
#    '(1)O2',
#    ')',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 3,
#     'end': 4,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 1, 'end': 2, 'namedCaptures': []}}]}]},
#  {'sentenceId': 230098,
#   'label': None,
#   'documentId': '23935934',
#   'sentenceIndex': 2,
#   'words': ['Osteopontin',
#    '(',
#    'OPN',
#    ')',
#    'is',
#    'a',
#    'secreted',
#    'non-collagenous',
#    ',',
#    'sialic',
#    'acid',
#    'rich',
#    ',',
#    'chemokine-like',
#    'phosphoglycoprotein',
#    'that',
#    'facilitates',
#    'cell-matrix',
#    'interactions',
#    'and',
#    'promotes',
#    'tumor',
#    'progression',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 0, 'end': 1, 'namedCaptures': []}]},
#  {'sentenceId': 454396,
#   'label': None,
#   'documentId': '22354989',
#   'sentenceIndex': 5,
#   'words': ['We',
#    'propose',
#    'a',
#    'model',
#    'in',
#    'which',
#    'the',
#    'initiating',
#    'event',
#    'for',
#    'Gwl',
#    'activation',
#    'is',
#    'phosphorylation',
#    'by',
#    'MPF',
#    'of',
#    'the',
#    'proline-directed',
#    'sites',
#    'T193',
#    'and',
#    'T206',
#    'in',
#    'the',
#    'presumptive',
#    'activation',
#    'loop',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 8, 'end': 9, 'namedCaptures': []}]},
#  {'sentenceId': 351648,
#   'label': 'Phosphorylation',
#   'documentId': '21957203',
#   'sentenceIndex': 1,
#   'words': ['Cardiolipin',
#    '(',
#    'CL',
#    ')',
#    'is',
#    'a',
#    'unique',
#    'phospholipid',
#    '(',
#    'PL',
#    ')',
#    'found',
#    'in',
#    'the',
#    'mitochondria',
#    'of',
#    'mammalian',
#    'cells',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 7,
#     'end': 8,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 0, 'end': 1, 'namedCaptures': []}}]}]},
#  {'sentenceId': 8139,
#   'label': 'Phosphorylation',
#   'documentId': '21751345',
#   'sentenceIndex': 5,
#   'words': ['These',
#    'proteins',
#    'were',
#    ':',
#    'phosphoglucomutase',
#    ',',
#    'phosphoglucose',
#    'isomerase',
#    ',',
#    'S-adenosyl',
#    'methionine-dependent',
#    'methyltransferase',
#    'class',
#    'I',
#    ',',
#    'aldehyde',
#    'dehydrogenase',
#    ',',
#    'catalase',
#    ',',
#    '6-phosphogluconate',
#    'dehydrogenase',
#    ',',
#    'fumarylacetoacetate',
#    'hydrolase',
#    ',',
#    '4-hydroxyphenylpyruvic',
#    'dioxygenase',
#    ',',
#    'methylmalonate-semialdehyde',
#    'dehydrogenase',
#    ',',
#    'lysozyme',
#    ',',
#    'urate',
#    'oxidase',
#    ',',
#    'elongation',
#    'factor',
#    '2',
#    ',',
#    '60kDa',
#    'heat-shock',
#    'protein',
#    ',',
#    '58kDa',
#    'glucose-regulated',
#    'protein',
#    ',',
#    'cytokeratin',
#    'E7',
#    ',',
#    'type-II',
#    'keratin',
#    ',',
#    'intermediate',
#    'filament',
#    'proteins',
#    ',',
#    '17',
#    '-',
#    '-hydroxysteroid',
#    'dehydrogenase',
#    'type',
#    '4',
#    ',',
#    'and',
#    'kinase',
#    'suppressor',
#    'of',
#    'Ras1',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 4,
#     'end': 5,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 1, 'end': 2, 'namedCaptures': []}}]}]},
#  {'sentenceId': 205977,
#   'label': None,
#   'documentId': '24616519',
#   'sentenceIndex': 1,
#   'words': ['Nucleophosmin',
#    '(',
#    'NPM1',
#    ')',
#    'is',
#    'a',
#    'multifunctional',
#    'phospho-protein',
#    'with',
#    'critical',
#    'roles',
#    'in',
#    'ribosome',
#    'biogenesis',
#    ',',
#    'tumor',
#    'suppression',
#    ',',
#    'and',
#    'nucleolar',
#    'stress',
#    'response',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 0, 'end': 1, 'namedCaptures': []}]},
#  {'sentenceId': 469952,
#   'label': 'Phosphorylation',
#   'documentId': '22154263',
#   'sentenceIndex': 9,
#   'words': ['All',
#    'the',
#    'spectrum',
#    'features',
#    'indicate',
#    'that',
#    'Ca(9)Y(PO(4))(7):Eu(3',
#    '+',
#    ')',
#    'might',
#    'be',
#    'a',
#    'promising',
#    'phosphor',
#    'for',
#    'display',
#    'devices',
#    'or',
#    'w-LEDs',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 13,
#     'end': 14,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 6, 'end': 7, 'namedCaptures': []}}]}]},
#  {'sentenceId': 7764,
#   'label': None,
#   'documentId': '22162980',
#   'sentenceIndex': 2,
#   'words': ['LPA',
#    'is',
#    'a',
#    'bioactive',
#    'phospholipid',
#    'produced',
#    'by',
#    'activated',
#    'platelets',
#    'and',
#    'formed',
#    'during',
#    'the',
#    'oxidation',
#    'of',
#    'LDL',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 0, 'end': 1, 'namedCaptures': []}]},
#  {'sentenceId': 508027,
#   'label': None,
#   'documentId': '22355135',
#   'sentenceIndex': 2,
#   'words': ['While',
#    'syndapin',
#    'I',
#    'is',
#    'an',
#    'in',
#    'vitro',
#    'phosphoprotein',
#    ',',
#    'it',
#    'is',
#    'not',
#    'known',
#    'to',
#    'be',
#    'phosphorylated',
#    'in',
#    'neurons',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 1, 'end': 2, 'namedCaptures': []}]},
#  {'sentenceId': 508027,
#   'label': 'Phosphorylation',
#   'documentId': '22355135',
#   'sentenceIndex': 2,
#   'words': ['While',
#    'syndapin',
#    'I',
#    'is',
#    'an',
#    'in',
#    'vitro',
#    'phosphoprotein',
#    ',',
#    'it',
#    'is',
#    'not',
#    'known',
#    'to',
#    'be',
#    'phosphorylated',
#    'in',
#    'neurons',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 7,
#     'end': 8,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 1, 'end': 2, 'namedCaptures': []}}]}]},
#  {'sentenceId': 230098,
#   'label': 'Phosphorylation',
#   'documentId': '23935934',
#   'sentenceIndex': 2,
#   'words': ['Osteopontin',
#    '(',
#    'OPN',
#    ')',
#    'is',
#    'a',
#    'secreted',
#    'non-collagenous',
#    ',',
#    'sialic',
#    'acid',
#    'rich',
#    ',',
#    'chemokine-like',
#    'phosphoglycoprotein',
#    'that',
#    'facilitates',
#    'cell-matrix',
#    'interactions',
#    'and',
#    'promotes',
#    'tumor',
#    'progression',
#    '.'],
#   'foundBy': 'rule2',
#   'match': [{'start': 14,
#     'end': 15,
#     'namedCaptures': [{'name': 'subject',
#       'label': None,
#       'capturedMatch': {'start': 0, 'end': 1, 'namedCaptures': []}}]}]}]

# %%
duration = res.get("total_hits_duration")
query = res.get("query")
count = res.get("total_hits_count")
complete = True
total_hits = [item for key,value in res.get("total_hits").items() for item in value]

# %%
total_hits[0]
# Out:
# {'sentenceId': 509617,
#  'label': None,
#  'documentId': '12525665',
#  'sentenceIndex': 3,
#  'words': ['Protein',
#   'phosphatase',
#   '2A',
#   '(',
#   'PP2A',
#   ')',
#   'is',
#   'a',
#   'phosphoprotein',
#   'that',
#   'plays',
#   'important',
#   'roles',
#   'in',
#   'the',
#   'regulation',
#   'of',
#   'signal',
#   'transduction',
#   'and',
#   'cell',
#   'growth',
#   '.'],
#  'foundBy': 'rule2',
#  'match': [{'start': 2, 'end': 3, 'namedCaptures': []}]}

# %%
res.get("error_messages")
# Out:
# 'Expecting value: line 1 column 1 (char 0)'

# %%
grammar.urlList[1]
# Out:
# 'http://217.76.56.90:8000/'

# %%
res1 = grammar.query(url=grammar.urlList[1],
                     search_query=QUERY,
                     maxDocs=10,
                     triggerOverlap=False)
# Out:
# http://217.76.56.90:8000/api/execute/grammar
# {"metadataQuery":null,"duration":0.1599999964237213,"allowTriggerOverlaps":false,"mentions":[{"sentenceId":50302,"label":null,"documentId":"12392717","sentenceIndex":2,"words":["Although","CaM-kinase","II","weakly","phosphorylated","CaM","under","the","same","conditions",",","CaM-kinase","I",",","CaM-kinase","kinase","alpha",",","and","cAMP-dependent","protein","kinase","did","not","phosphorylate","CaM.","Polycations","such","as","poly(Lys",")","were","required","for","the","phosphorylation","."],"foundBy":"rule2","match":[{"start":1,"end":2,"namedCaptures":[]}]},{"sentenceId":50302,"label":null,"documentId":"12392717","sentenceIndex":2,"words":["Although","CaM-kinase","II","weakly","phosphorylated","CaM","under","the","same","conditions",",","CaM-kinase","I",",","CaM-kinase","kinase","alpha",",","and","cAMP-dependent","protein","kinase","did","not","phosphorylate","CaM.","Polycations","such","as","poly(Lys",")","were","required","for","the","phosphorylation","."],"foundBy":"rule2","match":[{"start":11,"end":12,"namedCaptures":[]}]},{"sentenceId":20715,"label":null,"documentId":"15138267","sentenceIndex":9,"words":["We","also","found","that","p90","RSK","directly","phosphorylates","CREB","on","Ser-133","following","BCR","cross-linking","and","is","positioned","downstream","of","nPKCdelta","."],"foundBy":"rule2","match":[{"start":5,"end":6,"namedCaptures":[]}]},{"sentenceId":103565,"label":"Phosphorylation","documentId":"12429345","sentenceIndex":1,"words":["Deoxycytidine","kinase","(","dCK",")","is","a","salvage","pathway","enzyme","that","can","phosphorylate","both","pyrimidine","and","purine","deoxynucleosides",",","including","important","antiviral","and","cytostatic","agents","."],"foundBy":"rule2","match":[{"start":12,"end":13,"namedCaptures":[{"name":"subject","label":null,"capturedMatch":{"start":10,"end":11,"namedCaptures":[]}}]}]},{"sentenceId":103565,"label":null,"documentId":"12429345","sentenceIndex":1,"words":["Deoxycytidine","kinase","(","dCK",")","is","a","salvage","pathway","enzyme","that","can","phosphorylate","both","pyrimidine","and","purine","deoxynucleosides",",","including","important","antiviral","and","cytostatic","agents","."],"foundBy":"rule2","match":[{"start":10,"end":11,"namedCaptures":[]}]},{"sentenceId":28199,"label":null,"documentId":"12213813","sentenceIndex":5,"words":["Similar","to","RSK1",",","the","cAMP-dependent","protein","kinase","A","(","PKA",")","phosphorylates","ER81","on","Ser(191)/Ser(216",")","."],"foundBy":"rule2","match":[{"start":8,"end":9,"namedCaptures":[]}]},{"sentenceId":33325,"label":null,"documentId":"14561777","sentenceIndex":2,"words":["In","mammals",",","their","activity","peaks","during","S","phase",",","when","they","phosphorylate","the","antisilencing","function","protein","1","(","ASF1",")",",","a","histone","chaperone","involved","in","replication-dependent","chromatin","assembly","."],"foundBy":"rule2","match":[{"start":11,"end":12,"namedCaptures":[]}]},{"sentenceId":50302,"label":"Phosphorylation","documentId":"12392717","sentenceIndex":2,"words":["Although","CaM-kinase","II","weakly","phosphorylated","CaM","under","the","same","conditions",",","CaM-kinase","I",",","CaM-kinase","kinase","alpha",",","and","cAMP-dependent","protein","kinase","did","not","phosphorylate","CaM.","Polycations","such","as","poly(Lys",")","were","required","for","the","phosphorylation","."],"foundBy":"rule2","match":[{"start":4,"end":5,"namedCaptures":[{"name":"subject","label":null,"capturedMatch":{"start":1,"end":2,"namedCaptures":[]}}]}]},{"sentenceId":50302,"label":"Phosphorylation","documentId":"12392717","sentenceIndex":2,"words":["Although","CaM-kinase","II","weakly","phosphorylated","CaM","under","the","same","conditions",",","CaM-kinase","I",",","CaM-kinase","kinase","alpha",",","and","cAMP-dependent","protein","kinase","did","not","phosphorylate","CaM.","Polycations","such","as","poly(Lys",")","were","required","for","the","phosphorylation","."],"foundBy":"rule2","match":[{"sta ...

# %%
res
# Out:
# {'total_hits': {},
#  'total_hits_count': 0,
#  'total_hits_duration': 0,
#  'error_messages': 'Expecting value: line 2 column 1 (char 1)'}

# %%
encoded_search_query = {"grammar":QUERY,
                        "maxDocs":10,
                        "allowTriggerOverlaps":False}

# %%
import requests

url = "http://217.76.56.90:8000/api/execute/grammar"
headers = {
    "Accept": "application/json",
    "Content-Type": "application/json"
}


response = requests.post(url,
                        headers=headers,
                        json=encoded_search_query)

print(response.text)

print(response.json())
# Out:
# {"metadataQuery":null,"duration":0.23899999260902405,"allowTriggerOverlaps":false,"mentions":[{"sentenceId":50302,"label":null,"documentId":"12392717","sentenceIndex":2,"words":["Although","CaM-kinase","II","weakly","phosphorylated","CaM","under","the","same","conditions",",","CaM-kinase","I",",","CaM-kinase","kinase","alpha",",","and","cAMP-dependent","protein","kinase","did","not","phosphorylate","CaM.","Polycations","such","as","poly(Lys",")","were","required","for","the","phosphorylation","."],"foundBy":"rule2","match":[{"start":1,"end":2,"namedCaptures":[]}]},{"sentenceId":50302,"label":null,"documentId":"12392717","sentenceIndex":2,"words":["Although","CaM-kinase","II","weakly","phosphorylated","CaM","under","the","same","conditions",",","CaM-kinase","I",",","CaM-kinase","kinase","alpha",",","and","cAMP-dependent","protein","kinase","did","not","phosphorylate","CaM.","Polycations","such","as","poly(Lys",")","were","required","for","the","phosphorylation","."],"foundBy":"rule2","match":[{"start":11,"end":12,"namedCaptures":[]}]},{"sentenceId":20715,"label":null,"documentId":"15138267","sentenceIndex":9,"words":["We","also","found","that","p90","RSK","directly","phosphorylates","CREB","on","Ser-133","following","BCR","cross-linking","and","is","positioned","downstream","of","nPKCdelta","."],"foundBy":"rule2","match":[{"start":5,"end":6,"namedCaptures":[]}]},{"sentenceId":103565,"label":"Phosphorylation","documentId":"12429345","sentenceIndex":1,"words":["Deoxycytidine","kinase","(","dCK",")","is","a","salvage","pathway","enzyme","that","can","phosphorylate","both","pyrimidine","and","purine","deoxynucleosides",",","including","important","antiviral","and","cytostatic","agents","."],"foundBy":"rule2","match":[{"start":12,"end":13,"namedCaptures":[{"name":"subject","label":null,"capturedMatch":{"start":10,"end":11,"namedCaptures":[]}}]}]},{"sentenceId":103565,"label":null,"documentId":"12429345","sentenceIndex":1,"words":["Deoxycytidine","kinase","(","dCK",")","is","a","salvage","pathway","enzyme","that","can","phosphorylate","both","pyrimidine","and","purine","deoxynucleosides",",","including","important","antiviral","and","cytostatic","agents","."],"foundBy":"rule2","match":[{"start":10,"end":11,"namedCaptures":[]}]},{"sentenceId":28199,"label":null,"documentId":"12213813","sentenceIndex":5,"words":["Similar","to","RSK1",",","the","cAMP-dependent","protein","kinase","A","(","PKA",")","phosphorylates","ER81","on","Ser(191)/Ser(216",")","."],"foundBy":"rule2","match":[{"start":8,"end":9,"namedCaptures":[]}]},{"sentenceId":33325,"label":null,"documentId":"14561777","sentenceIndex":2,"words":["In","mammals",",","their","activity","peaks","during","S","phase",",","when","they","phosphorylate","the","antisilencing","function","protein","1","(","ASF1",")",",","a","histone","chaperone","involved","in","replication-dependent","chromatin","assembly","."],"foundBy":"rule2","match":[{"start":11,"end":12,"namedCaptures":[]}]},{"sentenceId":50302,"label":"Phosphorylation","documentId":"12392717","sentenceIndex":2,"words":["Although","CaM-kinase","II","weakly","phosphorylated","CaM","under","the","same","conditions",",","CaM-kinase","I",",","CaM-kinase","kinase","alpha",",","and","cAMP-dependent","protein","kinase","did","not","phosphorylate","CaM.","Polycations","such","as","poly(Lys",")","were","required","for","the","phosphorylation","."],"foundBy":"rule2","match":[{"start":4,"end":5,"namedCaptures":[{"name":"subject","label":null,"capturedMatch":{"start":1,"end":2,"namedCaptures":[]}}]}]},{"sentenceId":50302,"label":"Phosphorylation","documentId":"12392717","sentenceIndex":2,"words":["Although","CaM-kinase","II","weakly","phosphorylated","CaM","under","the","same","conditions",",","CaM-kinase","I",",","CaM-kinase","kinase","alpha",",","and","cAMP-dependent","protein","kinase","did","not","phosphorylate","CaM.","Polycations","such","as","poly(Lys",")","were","required","for","the","phosphorylation","."],"foundBy":"rule2","match":[{"st ...
# {'metadataQuery': None, 'duration': 0.23899999260902405, 'allowTriggerOverlaps': False, 'mentions': [{'sentenceId': 50302, 'label': None, 'documentId': '12392717', 'sentenceIndex': 2, 'words': ['Although', 'CaM-kinase', 'II', 'weakly', 'phosphorylated', 'CaM', 'under', 'the', 'same', 'conditions', ',', 'CaM-kinase', 'I', ',', 'CaM-kinase', 'kinase', 'alpha', ',', 'and', 'cAMP-dependent', 'protein', 'kinase', 'did', 'not', 'phosphorylate', 'CaM.', 'Polycations', 'such', 'as', 'poly(Lys', ')', 'were', 'required', 'for', 'the', 'phosphorylation', '.'], 'foundBy': 'rule2', 'match': [{'start': 1, 'end': 2, 'namedCaptures': []}]}, {'sentenceId': 50302, 'label': None, 'documentId': '12392717', 'sentenceIndex': 2, 'words': ['Although', 'CaM-kinase', 'II', 'weakly', 'phosphorylated', 'CaM', 'under', 'the', 'same', 'conditions', ',', 'CaM-kinase', 'I', ',', 'CaM-kinase', 'kinase', 'alpha', ',', 'and', 'cAMP-dependent', 'protein', 'kinase', 'did', 'not', 'phosphorylate', 'CaM.', 'Polycations', 'such', 'as', 'poly(Lys', ')', 'were', 'required', 'for', 'the', 'phosphorylation', '.'], 'foundBy': 'rule2', 'match': [{'start': 11, 'end': 12, 'namedCaptures': []}]}, {'sentenceId': 20715, 'label': None, 'documentId': '15138267', 'sentenceIndex': 9, 'words': ['We', 'also', 'found', 'that', 'p90', 'RSK', 'directly', 'phosphorylates', 'CREB', 'on', 'Ser-133', 'following', 'BCR', 'cross-linking', 'and', 'is', 'positioned', 'downstream', 'of', 'nPKCdelta', '.'], 'foundBy': 'rule2', 'match': [{'start': 5, 'end': 6, 'namedCaptures': []}]}, {'sentenceId': 103565, 'label': 'Phosphorylation', 'documentId': '12429345', 'sentenceIndex': 1, 'words': ['Deoxycytidine', 'kinase', '(', 'dCK', ')', 'is', 'a', 'salvage', 'pathway', 'enzyme', 'that', 'can', 'phosphorylate', 'both', 'pyrimidine', 'and', 'purine', 'deoxynucleosides', ',', 'including', 'important', 'antiviral', 'and', 'cytostatic', 'agents', '.'], 'foundBy': 'rule2', 'match': [{'start': 12, 'end': 13, 'namedCaptures': [{'name': 'subject', 'label': None, 'capturedMatch': {'start': 10, 'end': 11, 'namedCaptures': []}}]}]}, {'sentenceId': 103565, 'label': None, 'documentId': '12429345', 'sentenceIndex': 1, 'words': ['Deoxycytidine', 'kinase', '(', 'dCK', ')', 'is', 'a', 'salvage', 'pathway', 'enzyme', 'that', 'can', 'phosphorylate', 'both', 'pyrimidine', 'and', 'purine', 'deoxynucleosides', ',', 'including', 'important', 'antiviral', 'and', 'cytostatic', 'agents', '.'], 'foundBy': 'rule2', 'match': [{'start': 10, 'end': 11, 'namedCaptures': []}]}, {'sentenceId': 28199, 'label': None, 'documentId': '12213813', 'sentenceIndex': 5, 'words': ['Similar', 'to', 'RSK1', ',', 'the', 'cAMP-dependent', 'protein', 'kinase', 'A', '(', 'PKA', ')', 'phosphorylates', 'ER81', 'on', 'Ser(191)/Ser(216', ')', '.'], 'foundBy': 'rule2', 'match': [{'start': 8, 'end': 9, 'namedCaptures': []}]}, {'sentenceId': 33325, 'label': None, 'documentId': '14561777', 'sentenceIndex': 2, 'words': ['In', 'mammals', ',', 'their', 'activity', 'peaks', 'during', 'S', 'phase', ',', 'when', 'they', 'phosphorylate', 'the', 'antisilencing', 'function', 'protein', '1', '(', 'ASF1', ')', ',', 'a', 'histone', 'chaperone', 'involved', 'in', 'replication-dependent', 'chromatin', 'assembly', '.'], 'foundBy': 'rule2', 'match': [{'start': 11, 'end': 12, 'namedCaptures': []}]}, {'sentenceId': 50302, 'label': 'Phosphorylation', 'documentId': '12392717', 'sentenceIndex': 2, 'words': ['Although', 'CaM-kinase', 'II', 'weakly', 'phosphorylated', 'CaM', 'under', 'the', 'same', 'conditions', ',', 'CaM-kinase', 'I', ',', 'CaM-kinase', 'kinase', 'alpha', ',', 'and', 'cAMP-dependent', 'protein', 'kinase', 'did', 'not', 'phosphorylate', 'CaM.', 'Polycations', 'such', 'as', 'poly(Lys', ')', 'were', 'required', 'for', 'the', 'phosphorylation', '.'], 'foundBy': 'rule2', 'match': [{'start': 4, 'end': 5, 'namedCaptures': [{'name': 'subject', 'label': None, 'capturedMatch': {'start': 1, 'end': 2, 'namedCaptures': []}}]}]}, {'sentenceId': 50302, 'label': 'Phosphorylation', ...

# %%
print(""" {
  "grammar": "# an example grammar\nrules:\n - name: \"example\"\n   label: GrammaticalSubject\n   type: event\n   pattern: |\n     trigger = [lemma=have]\n     subject  = >nsubj []\n",
  "maxDocs": 10,
  "allowTriggerOverlaps": false
}""")
# Out:
#  {
#   "grammar": "# an example grammar
# rules:
#  - name: "example"
#    label: GrammaticalSubject
#    type: event
#    pattern: |
#      trigger = [lemma=have]
#      subject  = >nsubj []
# ",
#   "maxDocs": 10,
#   "allowTriggerOverlaps": false
# }
